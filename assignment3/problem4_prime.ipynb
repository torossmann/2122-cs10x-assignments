# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your student ID number below. Please also delete all lines that say `raise NotImplementedError()`. Finally, make sure that your solutions are not commented out.

# %%
ID = ""

# %% [markdown]
# ---

# %% [markdown]
# ### CS102/CS103
# Tobias Rossmann<br>
# School of Mathematical and Statistical Sciences<br>
# NUI Galway
#
# # Assignment 3
# ## Problem 4 (12 marks)

# %% [markdown]
# A positive integer $n$ is a prime if and only if (a) $n > 1$ and (b) no integer $q$ with $2 \leqslant q \leqslant n-1$ divides $n$.
# Write a function `is_prime` that takes as input parameter a positive integer `n` and returns `True` or `False` according to whether `n` is or is not prime.

# %%
def is_prime(n):
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
assert not is_prime(1)

# %%
assert is_prime(2)

# %%
assert is_prime(3) and is_prime(5) and is_prime(7) and is_prime(11) and is_prime(13)

# %%
assert not(is_prime(4) or is_prime(6) or is_prime(8) or is_prime(9) or is_prime(10) or is_prime(12))
